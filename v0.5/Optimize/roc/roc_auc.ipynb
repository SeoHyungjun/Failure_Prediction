# %%
import numpy as np
from sklearn.metrics import auc, roc_auc_score

model = "rf"
filename = "1day/" + model + "_roc"

tpr = np.loadtxt(filename + "_tpr.csv", delimiter=",")
print(tpr)
print()
fpr = np.loadtxt(filename + "_fpr.csv", delimiter=",")
print(fpr)
print()

print(auc(fpr, tpr))
# Out:
# [0.         0.29986053 0.30404463 0.38493724 0.42956764 0.45467225
#  0.47001395 0.48117155 0.49790795 0.50627615 0.51603905 0.52301255
#  0.53417015 0.53695955 0.54393305 0.55509066 0.55788006 0.56206416
#  0.57043236 0.57182706 0.57461646 0.58298466 0.58437936 0.58716876
#  0.59135286 0.59414226 0.59832636 0.60111576 0.60251046 0.60669456
#  0.60669456 0.60808926 0.60808926 0.61366806 0.61785216 0.61924686
#  0.62482566 0.62900976 0.63458856 0.64853556 0.65132497 0.66806137
#  0.66806137 0.67224547 0.67503487 0.68619247 0.68898187 0.69456067
#  0.69735007 0.70432357 0.70711297 0.75174338 0.75174338 0.75313808
#  0.75313808 0.75453278 0.75453278 0.76011158 0.76011158 0.76150628
#  0.76150628 0.76290098 0.76290098 0.76708508 0.76708508 0.76987448
#  0.76987448 0.77126918 0.77126918 0.77405858 0.77405858 0.77545328
#  0.77545328 0.77824268 0.77824268 0.77963738 0.77963738 0.78103208
#  0.78103208 0.78242678 0.78242678 0.78382148 0.78382148 0.78800558
# ...
